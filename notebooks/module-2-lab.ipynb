# %% [markdown]
# # Module 2 Lab: Risk stratification and prediction
#
# Build or specify a risk stratification model.
#
# This executable lab is intentionally compact so it runs in GitHub Actions and student Codespaces.

# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(2)
x = np.linspace(0, 1, 24)
signal = np.sin((module + 1) * np.pi * x) if (module := 2) else x
noise = rng.normal(0, 0.08, size=x.shape)
y = signal + noise

plt.figure(figsize=(6, 3))
plt.plot(x, signal, label="reference")
plt.scatter(x, y, label="observed", s=18)
plt.title("Module 2 Lab: Risk stratification and prediction")
plt.legend()
plt.tight_layout()

# %%
summary = {
    "mean_observed": float(np.mean(y)),
    "std_observed": float(np.std(y)),
    "interpretation": "Replace with your interpretation of the pattern and its limits.",
}
summary
