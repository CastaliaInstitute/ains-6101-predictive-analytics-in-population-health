# %% [markdown]
# # Module 7 Assignment: Privacy and public-health governance
#
# Apply the module question to a realistic healthcare ai scenario: **What safeguards are required for sensitive population data?**
#
# ## Deliverable
#
# Submit a technical memo, notebook outputs, and any reproducible artifacts requested by the instructor.

# %%
# Starter workspace for Module 7
module = 7
claim = "Replace this with the claim your work supports."
evidence = ["dataset or source", "method", "result"]
{"module": module, "claim": claim, "evidence": evidence}
