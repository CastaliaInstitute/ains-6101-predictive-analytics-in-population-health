# %% [markdown]
# # Module 7: Privacy and public-health governance
#
# AINS6101 — Predictive Analytics in Population Health

# %% [markdown]
# # Essential Question
#
# What safeguards are required for sensitive population data?

# %% [markdown]
# # Scenario
#
# a population health team prioritizing outreach for patients with elevated near-term risk
#
# Stakeholders: population health director, care manager, privacy officer, and community advisory representative

# %% [markdown]
# # Core Moves
#
# - Define the decision boundary
# - Compare baseline and alternative
# - Interpret evidence and assumptions
# - Identify failure modes
# - Recommend next action

# %% [markdown]
# # Lab & Assignment
#
# Draft a governance memo.
#
# Artifact: risk stratification brief with equity checks, intervention criteria, and monitoring plan focused on privacy and public-health governance: Draft a governance memo.
