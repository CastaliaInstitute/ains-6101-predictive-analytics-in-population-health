# %% [markdown]
# # Module 4: Forecasting and surveillance
#
# AINS6101 — Predictive Analytics in Population Health

# %% [markdown]
# # Essential Question
#
# How do models support trend detection?

# %% [markdown]
# # Scenario
#
# a population health team prioritizing outreach for patients with elevated near-term risk
#
# Stakeholders: population health director, care manager, privacy officer, and community advisory representative

# %% [markdown]
# # Core Moves
#
# - Define the decision boundary
# - Compare baseline and alternative
# - Interpret evidence and assumptions
# - Identify failure modes
# - Recommend next action

# %% [markdown]
# # Lab & Assignment
#
# Create a simple forecast and uncertainty summary.
#
# Artifact: risk stratification brief with equity checks, intervention criteria, and monitoring plan focused on forecasting and surveillance: Create a simple forecast and uncertainty summary.
